# %%
#Importing libraries needed
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#opening the dataset needed to get city name 
#http://www.weathergraphics.com/identifiers/
matthew = pd.read_csv(r'data\Matthew.csv')
irma =  pd.read_csv(r'data\Irma.csv')
michael =  pd.read_csv(r'data\Michael.csv')
location = pd.read_csv(r'data\stationlocation.csv')

# %%
matthew.head()
# Out:
#        STATION                      NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1FLOK0029  MARY ESTHER 0.6 E, FL US  30.410900 -86.647500        4.9
# 1  USC00080737        BIG CYPRESS, FL US  26.328300 -80.995800        4.6
# 2  USC00082915      FEDERAL POINT, FL US  29.755000 -81.538900        1.5
# 3  US1FLVL0038   OAK HILL 2.8 WSW, FL US  28.860597 -80.871231        1.8
# 4  US1FLBV0023      COCOA 2.6 WNW, FL US  28.395600 -80.786800        7.0
#
#         DATE  AWND AWND_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  ...  WT07  \
# 0  10/8/2016   NaN             NaN   NaN             NaN  ...   NaN
# 1  10/8/2016   NaN             NaN   NaN             NaN  ...   NaN
# 2  10/8/2016   NaN             NaN   NaN             NaN  ...   NaN
# 3  10/8/2016   NaN             NaN   NaN             NaN  ...   NaN
# 4  10/8/2016   NaN             NaN   NaN             NaN  ...   NaN
#
#   WT07_ATTRIBUTES  WT08 WT08_ATTRIBUTES  WT09 WT09_ATTRIBUTES  WT10  \
# ...

# %%
matthew = matthew[['STATION', 'LATITUDE', 'LONGITUDE', 'NAME']]
matthew.head()
# Out:
#        STATION   LATITUDE  LONGITUDE                      NAME
# 0  US1FLOK0029  30.410900 -86.647500  MARY ESTHER 0.6 E, FL US
# 1  USC00080737  26.328300 -80.995800        BIG CYPRESS, FL US
# 2  USC00082915  29.755000 -81.538900      FEDERAL POINT, FL US
# 3  US1FLVL0038  28.860597 -80.871231   OAK HILL 2.8 WSW, FL US
# 4  US1FLBV0023  28.395600 -80.786800      COCOA 2.6 WNW, FL US

# %%
location.loc[location['lat'] == 30.410900]
# Out:
# Empty DataFrame
# Columns: [place_name, lat, lon, ghcn, station_name]
# Index: []

# %%
matthew.loc[matthew['LATITUDE'] == 28.707474]
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, LONGITUDE, NAME]
# Index: []

# %%
location.head()
# Out:
#   country3 country2        country region                  subregion  \
# 0      USA       US  United States     FL            Franklin County
# 1      USA       US  United States     FL            Franklin County
# 2      USA       US  United States     FL              Orange County
# 3      USA       US  United States     FL  Yukon-Koyukuk Census Area
# 4      USA       US  United States     FL              DeSoto County
#
#                                  place_name  \
# 0                     Apalachicola|Franklin
# 1          Apalachicola|Saint George Island
# 2  Apopka|Zellwood Station Mobile Home Park
# 3                    Arcadia|Arctic Village
# 4                            Arcadia|Joshua
#
#                               station_name type   stn_key status  icao  \
# 0  Apalachicola / Rgnl AP|Apalachicola AAF  NaN  USaaKAAF      -  KAAF
# 1          Apalachicola / St George Island  NaN  USfxxF47      -  KF47
# ...

# %%
location = location[['place_name', 'lat', 'lon', 'ghcn', 'station_name']]
location.head()
# Out:
#                                  place_name        lat         lon  \
# 0                     Apalachicola|Franklin  29.727550  -85.027378
# 1          Apalachicola|Saint George Island  29.644584  -84.915599
# 2  Apopka|Zellwood Station Mobile Home Park  28.707474  -81.581964
# 3                    Arcadia|Arctic Village  68.114669 -145.579415
# 4                            Arcadia|Joshua  27.183300  -81.766700
#
#           ghcn                             station_name
# 0  USW00012832  Apalachicola / Rgnl AP|Apalachicola AAF
# 1          NaN          Apalachicola / St George Island
# 2          NaN                           Orlando Apopka
# 3          NaN        Arcadia / Carlstrom Field (ABAND)
# 4  USW00012869         Arcadia / Dorr Aux Af #4 (ABAND)

# %%
location.rename(columns={"ghcn": "STATION"})
# Out:
#                                    place_name        lat         lon  \
# 0                       Apalachicola|Franklin  29.727550  -85.027378
# 1            Apalachicola|Saint George Island  29.644584  -84.915599
# 2    Apopka|Zellwood Station Mobile Home Park  28.707474  -81.581964
# 3                      Arcadia|Arctic Village  68.114669 -145.579415
# 4                              Arcadia|Joshua  27.183300  -81.766700
# ..                                        ...        ...         ...
# 264                                       NaN  26.143000  -80.344000
# 265                                       NaN  28.344000  -81.326000
# 266                                       NaN  25.758000  -80.491000
# 267                                       NaN  26.688000  -80.273000
# 268                                       NaN  27.860000  -82.518000
#
#          STATION                             station_name
# 0    USW00012832  Apalachicola / Rgnl AP|Apalachicola AAF
# ...

# %%
frames = [location, matthew]

result = pd.concat(frames)

result.head()
# Out:
#                                  place_name        lat         lon  \
# 0                     Apalachicola|Franklin  29.727550  -85.027378
# 1          Apalachicola|Saint George Island  29.644584  -84.915599
# 2  Apopka|Zellwood Station Mobile Home Park  28.707474  -81.581964
# 3                    Arcadia|Arctic Village  68.114669 -145.579415
# 4                            Arcadia|Joshua  27.183300  -81.766700
#
#           ghcn                             station_name STATION  LATITUDE  \
# 0  USW00012832  Apalachicola / Rgnl AP|Apalachicola AAF     NaN       NaN
# 1          NaN          Apalachicola / St George Island     NaN       NaN
# 2          NaN                           Orlando Apopka     NaN       NaN
# 3          NaN        Arcadia / Carlstrom Field (ABAND)     NaN       NaN
# 4  USW00012869         Arcadia / Dorr Aux Af #4 (ABAND)     NaN       NaN
#
#    LONGITUDE NAME
# 0        NaN  NaN
# 1        NaN  NaN
# 2        NaN  NaN
# 3        NaN  NaN
# 4        NaN  NaN

# %%
result.isnull().sum()
# Out:
# place_name      1720
# lat             1715
# lon             1715
# ghcn            1857
# station_name    1715
# STATION          269
# LATITUDE         269
# LONGITUDE        269
# NAME             269
# dtype: int64

# %%
result.dropisna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 result.dropisna()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dropisna'

# %%
#https://www.ncei.noaa.gov/access/homr/reports/mshr
name = pd.read_csv(r'data\mshr.txt', sep=" ", on_bad_lines='skip')
name.head()
# Out:
#     AK-AB-1  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  AK-AB-12         NaN         NaN         NaN         NaN         NaN
# 1  AK-AB-14         NaN         NaN         NaN         NaN         NaN
# 2  AK-AB-15         NaN         NaN         NaN         NaN         NaN
# 3  AK-AB-21         NaN         NaN         NaN         NaN         NaN
# 4  AK-AB-22         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 1649  \
# 0         NaN         NaN         NaN         NaN  ...           NaN
# 1         NaN         NaN         NaN         NaN  ...           NaN
# 2         NaN         NaN         NaN         NaN  ...           NaN
# 3         NaN         NaN         NaN         NaN  ...           NaN
# 4         NaN         NaN         NaN         NaN  ...           NaN
#
#   Unnamed: 1650 Unnamed: 1651 Unnamed: 1652 Unnamed: 1653 Unnamed: 1654  \
# ...

# %%
data=pd.read_table(r'data\mshr.txt', delimiter = ' ', on_bad_lines='skip')

# %%
data.head()
# Out:
#     AK-AB-1  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  AK-AB-12         NaN         NaN         NaN         NaN         NaN
# 1  AK-AB-14         NaN         NaN         NaN         NaN         NaN
# 2  AK-AB-15         NaN         NaN         NaN         NaN         NaN
# 3  AK-AB-21         NaN         NaN         NaN         NaN         NaN
# 4  AK-AB-22         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 1649  \
# 0         NaN         NaN         NaN         NaN  ...           NaN
# 1         NaN         NaN         NaN         NaN  ...           NaN
# 2         NaN         NaN         NaN         NaN  ...           NaN
# 3         NaN         NaN         NaN         NaN  ...           NaN
# 4         NaN         NaN         NaN         NaN  ...           NaN
#
#   Unnamed: 1650 Unnamed: 1651 Unnamed: 1652 Unnamed: 1653 Unnamed: 1654  \
# ...
