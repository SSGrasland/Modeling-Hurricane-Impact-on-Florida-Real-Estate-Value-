# %%
#Importing libraries needed
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
irma =  pd.read_csv(r'data\irma_p.csv')
irma.head()
# Out:
#        STATION                      NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1FLOK0029  MARY ESTHER 0.6 E, FL US  30.410900 -86.647500        4.9
# 1  USC00082915      FEDERAL POINT, FL US  29.755000 -81.538900        1.5
# 2  US1FLVL0038   OAK HILL 2.8 WSW, FL US  28.860597 -80.871231        1.8
# 3  US1FLBV0023      COCOA 2.6 WNW, FL US  28.395600 -80.786800        7.0
# 4  US1FLVL0036    DE LAND 1.4 WSW, FL US  29.026388 -81.318228       24.4
#
#         DATE  AWND AWND_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  ...  WT08  \
# 0  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 1  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 2  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 3  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 4  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
#
#   WT08_ATTRIBUTES  WT09 WT09_ATTRIBUTES  WT10  WT10_ATTRIBUTES  WT11  \
# ...

# %%
value = pd.read_csv(r'data\Sale_Prices_City.csv')
value.head()
# Out:
#    Unnamed: 0  RegionID    RegionName StateName  SizeRank   2015-10   2015-11  \
# 0          12     25290  Jacksonville   Florida        13   98900.0   98700.0
# 1          20     13121       Orlando   Florida        21  169900.0  172800.0
# 2          38     12700         Miami   Florida        39  286500.0  291800.0
# 3          53     41176         Tampa   Florida        54  158400.0  161400.0
# 4          71     19533        Naples   Florida        72  275100.0  281300.0
#
#     2015-12   2016-01   2016-02  ...  2019-01  2019-02  2019-03  2019-04  \
# 0   98900.0  100100.0  102100.0  ...   141900   146300   147400   153300
# 1  174700.0  176700.0  176400.0  ...   239900   241000   238700   239100
# 2  292100.0  289200.0  291800.0  ...   308300   307300   309500   316500
# 3  157800.0  167800.0  168500.0  ...   229800   227600   219900   220700
# 4  287600.0  297600.0  290800.0  ...   310700   309000   310500   313000
#
#    2019-05  2019-06  2019-07  2019-08  2019-09   2019-10
# ...

# %%
value_s = value.head(10)
value_s.head()
# Out:
#    Unnamed: 0  RegionID    RegionName StateName  SizeRank   2015-10   2015-11  \
# 0          12     25290  Jacksonville   Florida        13   98900.0   98700.0
# 1          20     13121       Orlando   Florida        21  169900.0  172800.0
# 2          38     12700         Miami   Florida        39  286500.0  291800.0
# 3          53     41176         Tampa   Florida        54  158400.0  161400.0
# 4          71     19533        Naples   Florida        72  275100.0  281300.0
#
#     2015-12   2016-01   2016-02  ...  2019-01  2019-02  2019-03  2019-04  \
# 0   98900.0  100100.0  102100.0  ...   141900   146300   147400   153300
# 1  174700.0  176700.0  176400.0  ...   239900   241000   238700   239100
# 2  292100.0  289200.0  291800.0  ...   308300   307300   309500   316500
# 3  157800.0  167800.0  168500.0  ...   229800   227600   219900   220700
# 4  287600.0  297600.0  290800.0  ...   310700   309000   310500   313000
#
#    2019-05  2019-06  2019-07  2019-08  2019-09   2019-10
# ...

# %%
#https://geopandas.org/en/stable/docs/user_guide/geocoding.html
#https://geopandas.org/en/stable/docs/user_guide/mergingdata.html
    
geo_s = geopandas.tools.geocode(value_s.RegionName)

# %%
irma['geometry'] = irma[['Points']]
irma.head()
# Out:
#        STATION                      NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1FLOK0029  MARY ESTHER 0.6 E, FL US  30.410900 -86.647500        4.9
# 1  USC00082915      FEDERAL POINT, FL US  29.755000 -81.538900        1.5
# 2  US1FLVL0038   OAK HILL 2.8 WSW, FL US  28.860597 -80.871231        1.8
# 3  US1FLBV0023      COCOA 2.6 WNW, FL US  28.395600 -80.786800        7.0
# 4  US1FLVL0036    DE LAND 1.4 WSW, FL US  29.026388 -81.318228       24.4
#
#         DATE  AWND AWND_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  ...  \
# 0  9/11/2017   NaN             NaN   NaN             NaN  ...
# 1  9/11/2017   NaN             NaN   NaN             NaN  ...
# 2  9/11/2017   NaN             NaN   NaN             NaN  ...
# 3  9/11/2017   NaN             NaN   NaN             NaN  ...
# 4  9/11/2017   NaN             NaN   NaN             NaN  ...
#
#    WT08_ATTRIBUTES WT09  WT09_ATTRIBUTES WT10  WT10_ATTRIBUTES  WT11  \
# 0              NaN  NaN              NaN  NaN              NaN   NaN
# ...

# %%
value_s.sjoin_nearest(irma, distance_col = dist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 value_s.sjoin_nearest(i, distance_col = dist)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sjoin_nearest'

# %%
s = geopandas.GeoDataFrame(value_s, crs=4326, geometry = 'geometry')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 s = geopandas.GeoDataFrame(value_s, crs=4326)
#
# File ~\anaconda3\lib\site-packages\geopandas\geodataframe.py:194, in GeoDataFrame.__init__(self, data, geometry, crs, *args, **kwargs)
#     191     self.set_geometry(geometry, inplace=True, crs=crs)
#     193 if geometry is None and crs:
# --> 194     raise ValueError(
#     195         "Assigning CRS to a GeoDataFrame without a geometry column is not "
#     196         "supported. Supply geometry using the 'geometry=' keyword argument, "
#     197         "or by providing a DataFrame with column name 'geometry'",
#     198     )
#
# ValueError: Assigning CRS to a GeoDataFrame without a geometry column is not supported. Supply geometry using the 'geometry=' keyword argument, or by providing a DataFrame with column name 'geometry'

# %%
i = geopandas.GeoDataFrame(irma, crs=4326)

# %%
i.set_geometry("geometry")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 i.set_geometry("geometry")
#
# File ~\anaconda3\lib\site-packages\geopandas\geodataframe.py:348, in GeoDataFrame.set_geometry(self, col, drop, inplace, crs)
#     345     level.crs = crs
#     347 # Check that we are using a listlike of geometries
# --> 348 level = _ensure_geometry(level, crs=crs)
#     349 # update _geometry_column_name prior to assignment
#     350 # to avoid default is None warning
#     351 frame._geometry_column_name = geo_column_name
#
# File ~\anaconda3\lib\site-packages\geopandas\geodataframe.py:56, in _ensure_geometry(data, crs)
#      54 else:
#      55     if isinstance(data, Series):
# ---> 56         out = from_shapely(np.asarray(data), crs=crs)
#      57         return GeoSeries(out, index=data.index, name=data.name)
#      58     else:
#
# ...

# %%
geo_s.sjoin_nearest(i, distance_col = 'dist')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\geopandas\geodataframe.py:436, in GeoDataFrame.crs(self)
#     435 try:
# --> 436     return self.geometry.crs
#     437 except AttributeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\geopandas\geodataframe.py:235, in GeoDataFrame._get_geometry(self)
#     229         msg += (
#     230             "\nThere are no existing columns with geometry data type. You can "
#     231             "add a geometry column as the active geometry column with "
#     232             "df.set_geometry. "
#     233         )
# --> 235     raise AttributeError(msg)
#     236 return self[self._geometry_column_name]
#
# ...

# %%
i['geometry']=geopandas.GeoSeries.from_xy(i['LATITUDE'], i['LONGITUDE'])
i.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 45 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATION          1058 non-null   object
#  1   NAME             1058 non-null   object
#  2   LATITUDE         1058 non-null   float64
#  3   LONGITUDE        1058 non-null   float64
#  4   ELEVATION        1047 non-null   float64
#  5   DATE             1058 non-null   object
#  6   AWND             77 non-null     float64
#  7   AWND_ATTRIBUTES  77 non-null     object
#  8   PGTM             23 non-null     float64
#  9   PGTM_ATTRIBUTES  23 non-null     object
#  10  WDF2             83 non-null     float64
#  11  WDF2_ATTRIBUTES  83 non-null     object
#  12  WDF5             83 non-null     float64
#  13  WDF5_ATTRIBUTES  83 non-null     object
#  14  WDMV             0 non-null      float64
#  15  WDMV_ATTRIBUTES  0 non-null      float64
# ...

# %%
geo_s.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   geometry  10 non-null     geometry
#  1   address   10 non-null     object
# dtypes: geometry(1), object(1)
# memory usage: 240.0+ bytes
