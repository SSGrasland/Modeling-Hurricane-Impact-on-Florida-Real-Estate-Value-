# %% [markdown]
# #### Homework
# Use geopy to convert lat and long to cities
# Use that and join the datasets
# Run a logistical regression using the combined dataset
# Plot the output of the predict_probability (predict_proba(X)) method (the probablity estimates to see if it's lining us   with the S curve)
# One interpretation of the coefficient of that model

# %% [markdown]
# # Importing Libraries

# %%
#Importing libraries needed
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Column Description
# NOAA Data
# Average wind speed (AWND)
# Peak gust time (PGTM)
# Direction of fastest 2-minute wind (WDF2) (in degrees)
# Direction of fastest 5-second wind (WDF5) (in degrees)
# Fastest 2-minute wind speed (WSF2) (in meters per second)
# Fastest 5-second wind speed (WSF5) (in meter per second)
# 24-hour wind movement (km or miles as per user preference, miles on Daily Form pdf file) (WDMV)
# Weather types (WT**)

# %% [markdown]
# ## Loading Dataset

# %%
irma =  pd.read_csv(r'data\irma_city.csv')
irma.head()
# Out:
#                                                 NAME       DATE   AWND  WSF2  \
# 0  FORT PIERCE ST LUCIE CO INTERNATIONAL AIRPORT,...  9/11/2017  17.45  44.1
# 1      FORT MYERS SW FLORIDA REGIONAL AIRPORT, FL US  9/11/2017  19.24  45.0
# 2  NORTHWEST FLORIDA BEACHES INTERNATIONAL AIRPOR...  9/11/2017  19.01  30.0
# 3                      BONIFAY TRI CO AIRPORT, FL US  9/11/2017  13.42  23.0
# 4                     WHITING FIELD NAS SOUTH, FL US  9/11/2017  16.33  25.1
#
#    WSF5          coordinates
# 0  62.0  27.49816, -80.37626
# 1  59.1  26.53805, -81.75674
# 2  45.0  30.34869, -85.78835
# 3  42.9  30.84315, -85.60431
# 4  36.0  30.69729, -87.02073

# %% [markdown]
# ## Using Geopy to Extract Cities from Coordinates

# %%
#importing libraries 
from tkinter import *
from geopy.geocoders import Nominatim
from geopy.geocoders import Photon

# Create an instance of tkinter frame
win = Tk()

# Define geometry of the window
win.geometry("700x350")
# Out:
# ''

# %%
#creating a function 
def get_city(coords):
    #instantiate the Nominatim API 
    geolocator = Nominatim(user_agent="MyApp")
    #get the city from the coordinates 
    location = geolocator.reverse(coords)
    address = location.raw['address']
    city = address.get('city', '')
    #return the city 
    return city

# %%
#applying function to dataframe
irma['city'] = irma['coordinates'].apply(get_city)

# %%
#checking to see if cities were loaded 
irma.head()
# Out:
#                                                 NAME       DATE   AWND  WSF2  \
# 0  FORT PIERCE ST LUCIE CO INTERNATIONAL AIRPORT,...  9/11/2017  17.45  44.1
# 1      FORT MYERS SW FLORIDA REGIONAL AIRPORT, FL US  9/11/2017  19.24  45.0
# 2  NORTHWEST FLORIDA BEACHES INTERNATIONAL AIRPOR...  9/11/2017  19.01  30.0
# 3                      BONIFAY TRI CO AIRPORT, FL US  9/11/2017  13.42  23.0
# 4                     WHITING FIELD NAS SOUTH, FL US  9/11/2017  16.33  25.1
#
#    WSF5          coordinates        city
# 0  62.0  27.49816, -80.37626
# 1  59.1  26.53805, -81.75674  Fort Myers
# 2  45.0  30.34869, -85.78835
# 3  42.9  30.84315, -85.60431
# 4  36.0  30.69729, -87.02073

# %% [markdown]
# ## Trying Geopy with Photon

# %%
#creating a function 
def get_city_photon(coords):
    # Initialize Nominatim API
    geolocator = Photon(user_agent="MyApp")
    #get the city from the coordinates 
    location = geolocator.reverse(coords)
    address = location.raw['address']
    city = address.get('city', '')
    #return the city 
    return city

# %%
#applying function to dataframe
irma['city'] = irma['coordinates'].apply(get_city_photon)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 #applying function to dataframe
# ----> 2 irma['city'] = irma['coordinates'].apply(get_city_photon)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[7], line 7, in get_city_photon(coords)
#       5 #get the city from the coordinates
#       6 location = geolocator.reverse(coords)
# ----> 7 address = location.raw['address']
#       8 city = address.get('city', '')
#       9 #return the city
#
# KeyError: 'address'

# %%
irma.head()

# %% [markdown]
# # Alt City Method

# %%
#converting coordinates to a list 
coord = irma.coordinates.values.tolist()

#using map function to apply geolocator to all items in list 
geolocator = Nominatim(user_agent="MyApp")
location = map(geolocator.reverse, coord)

# %%
#saving the list to a dataframe 
df = pd.DataFrame(location, columns =['location', 'coordinates'], dtype = float) 
df
# Out:
#                                              location  \
# 0   3000, Curtis King Boulevard, Fort Pierce, Sain...
# 1   Southwest Florida International Airport, 11000...
# 2                  Bay County, Florida, United States
# 3   Tri-County Airport, Seminole Lane, Holmes Coun...
# 4   Whiting Field NAS South, Santa Rosa County, Fl...
# ..                                                ...
# 72  Northwest 24th Way, Fort Lauderdale, Broward C...
# 73  3441, Hamilton Road, Polk County, Florida, 338...
# 74  Miami Gardens, Miami-Dade County, Florida, 330...
# 75  South Ramp, Capital Circle Southwest, Tallahas...
# 76  Orlando Sanford International Airport, 1200, R...
#
#                                  coordinates
# 0                  (27.4976101, -80.3756695)
# 1          (26.53294975, -81.75880562612211)
# 2                  (30.2481693, -85.6593633)
# 3          (30.84475065, -85.60302893933712)
# 4   (30.696747315586343, -87.02160319146255)
# ..                                       ...
# 72                 (26.2011658, -80.1796717)
# 73   (28.000245682156468, -82.0499310622678)
# 74                  (25.9150507, -80.283763)
# 75         (30.39634345, -84.35334647210303)
# 76          (28.7754331, -81.24329602986423)
#
# [77 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   location     77 non-null     object
#  1   coordinates  77 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %%
location = df.location.values.tolist()

# %%
location
# Out:
# ['3000, Curtis King Boulevard, Fort Pierce, Saint Lucie County, Florida, 34946, United States',
#  'Southwest Florida International Airport, 11000, Terminal Access Road, Fort Myers, Lee County, Florida, 33913, United States',
#  'Bay County, Florida, United States',
#  'Tri-County Airport, Seminole Lane, Holmes County, Florida, 32425, United States',
#  'Whiting Field NAS South, Santa Rosa County, Florida, 32570, United States',
#  '1101, Airport Road, Destin, Okaloosa County, Florida, 32541, United States',
#  'Jacksonville Executive at Craig Airport, Charles Lindbergh Drive, Jacksonville, Duval County, Florida, 32225, United States',
#  'Pompano Beach Airpark, Northeast 10th Avenue, Pompano Beach, Broward County, Florida, 33060, United States',
#  'Albert Whitted Airport, 107, 8th Avenue Southeast, Saint Petersburg, Pinellas County, Florida, 33701, United States',
#  'General Aviation Parking, Southwest 77th Avenue, Pembroke Pines, Broward County, Florida, 33024, United States',
#  'Jacksonville International Airport, Pecan Park Road, Beeghly Heights, Jacksonville, Duval County, Florida, 32218, United States',
#  'Bob Sikes Airport, 5551, John Givens Road, Crestview, Okaloosa County, Florida, 32539, United States',
#  'Marianna Municipal Airport, Bryan Road, Marianna, Jackson County, Florida, 32446, United States',
#  'Pensacola International Airport, 2430, Airport Boulevard, Town Square Condominiums, Pensacola, Escambia County, Florida, 32504, United States',
#  'Patrol Road, Jacksonville, Duval County, Florida, 32228, United States',
#  '2566, Bellevue Avenue, Daytona Beach, Volusia County, Florida, 32114, United States',
#  'Cross City Airport, 508, Faith Manor, Cross City, Dixie County, Florida, 32628, United States',
#  'Apalachicola Regional Airport, Appalachee Street, Franklin County, Florida, 32320, United States',
#  'Duncan Avenue, Palm Beach County, Florida, 33416, United States',
#  'Vero Beach Municipal Airport, 3400, Cherokee Drive, Vero Beach, Indian River County, Florida, 32960, United States',
#  'Economy Parking Road, Tampa, Hillsborough County, Florida, 33607, United States',
#  'Orlando Executive Airport, Crystal Lake Drive, Orlando, Orange County, Florida, 32803, United States',
#  'Punta Gorda Airport, 28000 A-1, Airport Road, Punta Gorda, Charlotte County, Florida, 33982, United States',
#  'Uss Hornet Street, Santa Rosa County, Florida, 32570, United States',
#  'Leesburg International Airport, US 441, Leesburg, Tavares, Lake County, Florida, 34788, United States',
#  'Gainesville Regional Airport, Waldo Road, Gainesville, Alachua County, Florida, 32609, United States',
#  'FreeZone Street, Orlando, Orange County, Florida, 32862, United States',
#  'Catapult Road, Jacksonville, Duval County, Florida, 32212, United States',
#  'Winter Haven Municipal Airport, Caleb Way, Polk County, Florida, 33881, United States',
#  'Saint Petersburg-Clearwater International Airport, 14700, Terminal Boulevard, Clearwater, Pinellas County, Florida, 33762, United States',
#  'Clyde Jones Road, Ballentine Manor, Manatee County, Florida, 34243, United States',
#  'Northwest 24th Way, Fort Lauderdale, Broward County, Florida, 33309, United States',
#  '3441, Hamilton Road, Polk County, Florida, 33811, United States',
#  'Miami Gardens, Miami-Dade County, Florida, 33014, United States',
#  '100, Southwest 34th Street, Fort Lauderdale, Broward County, Florida, 33315, United States',
#  'South Ramp, Capital Circle Southwest, Tallahassee, Leon County, Florida, 32310, United States',
#  'Orlando Sanford International Airport, 1200, Red Cleveland Boulevard, Sanford, Seminole County, Florida, 32773, United States',
#  'Naples Municipal Airport, Janets Boulevard, Rock Creek RV Resort, Naples, Collier County, Florida, 34104, United States',
#  '3000, Curtis King Boulevard, Fort Pierce, Saint Lucie County, Florida, 34946, United States',
#  'Southwest Florida International Airport, 11000, Terminal Access Road, Fort Myers, Lee County, Florida, 33913, United States',
#  'Bay County, Florida, United States',
#  'Tri-County Airport, Seminole Lane, Holmes County, Florida, 32425, United States',
#  'Whiting Field NAS South, Santa Rosa County, Florida, 32570, United States',
#  '1101, Airport Road, Destin, Okaloosa County, Florida, 32541, United States',
#  'Jacksonville Executive at Craig Airport, Charles Lindbergh Drive, Jacksonville, Duval County, Florida, 32225, United States',
#  'Pompano Beach Airpark, Northeast 10th Avenue, Pompano Beach, Broward County, Florida, 33060, United States',
#  'Albert Whitted Airport, 107, 8th Avenue Southeast, Saint Petersburg, Pinellas County, Florida, 33701, United States',
#  'General Aviation Parking, Southwest 77th Avenue, Pembroke Pines, Broward County, Florida, 33024, United States',
#  'Jacksonville International Airport, Pecan Park Road, Beeghly Heights, Jacksonville, Duval County, Florida, 32218, United States',
#  'Bob Sikes Airport, 5551, John Givens Road, Crestview, Okaloosa County, Florida, 32539, United States',
#  'Marianna Municipal Airport, Bryan Road, Marianna, Jackson County, Florida, 32446, United States',
#  'Pensacola International Airport, 2430, Airport Boulevard, Town Square Condominiums, Pensacola, Escambia County, Florida, 32504, United States',
#  'Patrol Road, Jacksonville, Duval County, Florida, 32228, United States',
#  '2566, Bellevue Avenue, Daytona Beach, Volusia County, Florida, 32114, United States',
#  'Cross City Airport, 508, Faith Manor, Cross City, Dixie County, Florida, 32628, United States',
#  'Apalachicola Regional Airport, Appalachee Street, Franklin County, Florida, 32320, United States',
#  'Milam Dairy Road, Miami-Dade County, Florida, 33152, United States',
#  'Duncan Avenue, Palm Beach County, Florida, 33416, United States',
#  'Vero Beach Municipal Airport, 3400, Cherokee Drive, Vero Beach, Indian River County, Florida, 32960, United States',
#  'Economy Parking Road, Tampa, Hillsborough County, Florida, 33607, United States',
#  'Orlando Executive Airport, Crystal Lake Drive, Orlando, Orange County, Florida, 32803, United States',
#  'Punta Gorda Airport, 28000 A-1, Airport Road, Punta Gorda, Charlotte County, Florida, 33982, United States',
#  'Uss Hornet Street, Santa Rosa County, Florida, 32570, United States',
#  'Leesburg International Airport, US 441, Leesburg, Tavares, Lake County, Florida, 34788, United States',
#  'Brooksville-Tampa Bay Regional Airport, 15800, Flight Path Drive, South Brooksville, Hernando County, Florida, 34604, United States',
#  'Gainesville Regional Airport, Waldo Road, Gainesville, Alachua County, Florida, 32609, United States',
#  'FreeZone Street, Orlando, Orange County, Florida, 32862, United States',
#  'Catapult Road, Jacksonville, Duval County, Florida, 32212, United States',
#  'Winter Haven Municipal Airport, Caleb Way, Polk County, Florida, 33881, United States',
#  'Saint Petersburg-Clearwater International Airport, 14700, Terminal Boulevard, Clearwater, Pinellas County, Florida, 33762, United States',
#  'Clyde Jones Road, Ballentine Manor, Manatee County, Florida, 34243, United States',
#  'Southwest 136th Street, Country Walk, Miami-Dade County, Florida, 33196, United States',
#  'Northwest 24th Way, Fort Lauderdale, Broward County, Florida, 33309, United States',
#  '3441, Hamilton Road, Polk County, Florida, 33811, United States',
#  'Miami Gardens, Miami-Dade County, Florida, 33014, United States',
#  'South Ramp, Capital Circle Southwest, Tallahassee, Leon County, Florida, 32310, United States',
#  'Orlando Sanford International Airport, 1200, Red Cleveland Boulevard, Sanford, Seminole County, Florida, 32773, United States']

# %%
print(location.raw)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(location.raw)
#
# AttributeError: 'list' object has no attribute 'raw'

# %%
#saving the list to a dataframe split
split = pd.DataFrame(location, columns =['location', 'coordinates'], dtype = float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 #saving the list to a dataframe split
# ----> 2 split = pd.DataFrame(location, columns =['location', 'coordinates'], dtype = float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
#     777     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:335, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#     332     # GH#40110 see similar check inside sanitize_array
#     333     rcf = not (is_integer_dtype(dtype) and values.dtype.kind == "f")
# --> 335     values = sanitize_array(
#     336         values,
#     337         None,
#     338         dtype=dtype,
#     339         copy=copy_on_sanitize,
#     340         raise_cast_failure=rcf,
#     341         allow_2d=True,
#     342     )
#     344 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     345 index, columns = _get_axes(
#     346     values.shape[0], values.shape[1], index=index, columns=columns
#     347 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\construction.py:597, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     594             subarr = np.array(data, copy=copy)
#     595     else:
#     596         # we will try to copy by-definition here
# --> 597         subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     599 elif isinstance(data, ABCExtensionArray):
#     600     # it is already ensured above this is not a PandasArray
#     601     subarr = data
#
# File ~\anaconda3\lib\site-packages\pandas\core\construction.py:840, in _try_cast(arr, dtype, copy, raise_cast_failure)
#     835         subarr = maybe_cast_to_integer_array(arr, dtype)
#     836     else:
#     837         # 4 tests fail if we move this to a try/except/else; see
#     838         #  test_constructor_compound_dtypes, test_constructor_cast_failure
#     839         #  test_constructor_dict_cast2, test_loc_setitem_dtype
# --> 840         subarr = np.array(arr, dtype=dtype, copy=copy)
#     842 except (ValueError, TypeError):
#     843     if raise_cast_failure:
#
# ValueError: could not convert string to float: '3000, Curtis King Boulevard, Fort Pierce, Saint Lucie County, Florida, 34946, United States'

# %%
df.info()

# %%
df.to_csv(r'data\location.csv', index=False)

# %%
#we were able to extract the address for each entry 
#lets see if we can isolate the city 
#splitting the address to try to get just city 
split['location_list'] = split['location'].str.split(',')
split.info()

# %%
#creating a column for each item in the address 
split = pd.DataFrame(df['location_list'].tolist()).fillna('').add_prefix('model_')
split.head()

# %% [markdown]
# # Geopandas

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.13.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 6.3 MB/s eta 0:00:00
# Collecting pyproj>=3.0.1
#   Downloading pyproj-3.5.0-cp310-cp310-win_amd64.whl (5.1 MB)
#      ---------------------------------------- 5.1/5.1 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\salom\anaconda3\lib\site-packages (from geopandas) (22.0)
# Collecting fiona>=1.8.19
#   Downloading Fiona-1.9.4.post1-cp310-cp310-win_amd64.whl (22.7 MB)
#      ---------------------------------------- 22.7/22.7 MB 7.2 MB/s eta 0:00:00
# Collecting shapely>=1.7.1
#   Downloading shapely-2.0.1-cp310-cp310-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.0 in c:\users\salom\anaconda3\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: click~=8.0 in c:\users\salom\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: six in c:\users\salom\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\salom\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\salom\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\salom\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\salom\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\salom\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (1.23.5)
# Requirement already satisfied: colorama in c:\users\salom\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.6)
# Installing collected packages: shapely, pyproj, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.0 pyproj-3.5.0 shapely-2.0.1

# %%
irma.head()
# Out:
#                                                 NAME       DATE   AWND  WSF2  \
# 0  FORT PIERCE ST LUCIE CO INTERNATIONAL AIRPORT,...  9/11/2017  17.45  44.1
# 1      FORT MYERS SW FLORIDA REGIONAL AIRPORT, FL US  9/11/2017  19.24  45.0
# 2  NORTHWEST FLORIDA BEACHES INTERNATIONAL AIRPOR...  9/11/2017  19.01  30.0
# 3                      BONIFAY TRI CO AIRPORT, FL US  9/11/2017  13.42  23.0
# 4                     WHITING FIELD NAS SOUTH, FL US  9/11/2017  16.33  25.1
#
#    WSF5          coordinates        city
# 0  62.0  27.49816, -80.37626
# 1  59.1  26.53805, -81.75674  Fort Myers
# 2  45.0  30.34869, -85.78835
# 3  42.9  30.84315, -85.60431
# 4  36.0  30.69729, -87.02073

# %%
from shapely.geometry import Point

# %%
irma.coordinates[0]
# Out:
# '27.49816, -80.37626'

# %%
irma =  pd.read_csv(r'data\irma.csv')
irma.head()
# Out:
#        STATION                      NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1FLOK0029  MARY ESTHER 0.6 E, FL US  30.410900 -86.647500        4.9
# 1  USC00082915      FEDERAL POINT, FL US  29.755000 -81.538900        1.5
# 2  US1FLVL0038   OAK HILL 2.8 WSW, FL US  28.860597 -80.871231        1.8
# 3  US1FLBV0023      COCOA 2.6 WNW, FL US  28.395600 -80.786800        7.0
# 4  US1FLVL0036    DE LAND 1.4 WSW, FL US  29.026388 -81.318228       24.4
#
#         DATE  AWND AWND_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  ...  WT07  \
# 0  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 1  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 2  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 3  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 4  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
#
#   WT07_ATTRIBUTES  WT08 WT08_ATTRIBUTES  WT09  WT09_ATTRIBUTES  WT10  \
# 0             NaN   NaN             NaN   NaN              NaN   NaN
# 1             NaN   NaN             NaN   NaN              NaN   NaN
# 2             NaN   NaN             NaN   NaN              NaN   NaN
# 3             NaN   NaN             NaN   NaN              NaN   NaN
# 4             NaN   NaN             NaN   NaN              NaN   NaN
#
#   WT10_ATTRIBUTES  WT11 WT11_ATTRIBUTES
# 0             NaN   NaN             NaN
# 1             NaN   NaN             NaN
# 2             NaN   NaN             NaN
# 3             NaN   NaN             NaN
# 4             NaN   NaN             NaN
#
# [5 rows x 42 columns]

# %%
irma['list'] = irma[['LATITUDE', 'LONGITUDE']].values.tolist()
irma
# Out:
#           STATION                         NAME   LATITUDE  LONGITUDE  \
# 0     US1FLOK0029     MARY ESTHER 0.6 E, FL US  30.410900 -86.647500
# 1     USC00082915         FEDERAL POINT, FL US  29.755000 -81.538900
# 2     US1FLVL0038      OAK HILL 2.8 WSW, FL US  28.860597 -80.871231
# 3     US1FLBV0023         COCOA 2.6 WNW, FL US  28.395600 -80.786800
# 4     US1FLVL0036       DE LAND 1.4 WSW, FL US  29.026388 -81.318228
# ...           ...                          ...        ...        ...
# 1053  US1FLPK0007     AUBURNDALE 1.7 NW, FL US  28.090015 -81.815750
# 1054  USC00089176                VENICE, FL US  27.100600 -82.436400
# 1055  US1FLDV0066  JACKSONVILLE 4.2 ESE, FL US  30.301649 -81.599052
# 1056  US1FLDV0069  JACKSONVILLE 6.7 WSW, FL US  30.303307 -81.763550
# 1057  USC00083874         HASTINGS 4 NE, FL US  29.765200 -81.469700
#
#       ELEVATION       DATE  AWND AWND_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  ...  \
# 0           4.9  9/11/2017   NaN             NaN   NaN             NaN  ...
# 1           1.5  9/11/2017   NaN             NaN   NaN             NaN  ...
# 2           1.8  9/11/2017   NaN             NaN   NaN             NaN  ...
# 3           7.0  9/11/2017   NaN             NaN   NaN             NaN  ...
# 4          24.4  9/11/2017   NaN             NaN   NaN             NaN  ...
# ...         ...        ...   ...             ...   ...             ...  ...
# 1053       42.1  9/10/2017   NaN             NaN   NaN             NaN  ...
# 1054        2.4  9/10/2017   NaN             NaN   NaN             NaN  ...
# 1055        7.0  9/10/2017   NaN             NaN   NaN             NaN  ...
# 1056        8.5  9/10/2017   NaN             NaN   NaN             NaN  ...
# 1057        3.0  9/10/2017   NaN             NaN   NaN             NaN  ...
#
#       WT07_ATTRIBUTES WT08  WT08_ATTRIBUTES WT09  WT09_ATTRIBUTES  WT10  \
# 0                 NaN  NaN              NaN  NaN              NaN   NaN
# 1                 NaN  NaN              NaN  NaN              NaN   NaN
# 2                 NaN  NaN              NaN  NaN              NaN   NaN
# 3                 NaN  NaN              NaN  NaN              NaN   NaN
# 4                 NaN  NaN              NaN  NaN              NaN   NaN
# ...               ...  ...              ...  ...              ...   ...
# 1053              NaN  NaN              NaN  NaN              NaN   NaN
# 1054              NaN  NaN              NaN  NaN              NaN   NaN
# 1055              NaN  NaN              NaN  NaN              NaN   NaN
# 1056              NaN  NaN              NaN  NaN              NaN   NaN
# 1057              NaN  NaN              NaN  NaN              NaN   NaN
#
#       WT10_ATTRIBUTES WT11  WT11_ATTRIBUTES                         list
# 0                 NaN  NaN              NaN          [30.4109, -86.6475]
# 1                 NaN  NaN              NaN           [29.755, -81.5389]
# 2                 NaN  NaN              NaN      [28.860597, -80.871231]
# 3                 NaN  NaN              NaN          [28.3956, -80.7868]
# 4                 NaN  NaN              NaN  [29.02638751, -81.31822754]
# ...               ...  ...              ...                          ...
# 1053              NaN  NaN              NaN       [28.090015, -81.81575]
# 1054              NaN  NaN              NaN          [27.1006, -82.4364]
# 1055              NaN  NaN              NaN  [30.30164909, -81.59905243]
# 1056              NaN  NaN              NaN       [30.303307, -81.76355]
# 1057              NaN  NaN              NaN          [29.7652, -81.4697]
#
# [1058 rows x 43 columns]

# %%
from shapely.geometry import Point 
irma['Points'] = irma.list.apply(Point)
irma.head()
# Out:
#        STATION                      NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1FLOK0029  MARY ESTHER 0.6 E, FL US  30.410900 -86.647500        4.9
# 1  USC00082915      FEDERAL POINT, FL US  29.755000 -81.538900        1.5
# 2  US1FLVL0038   OAK HILL 2.8 WSW, FL US  28.860597 -80.871231        1.8
# 3  US1FLBV0023      COCOA 2.6 WNW, FL US  28.395600 -80.786800        7.0
# 4  US1FLVL0036    DE LAND 1.4 WSW, FL US  29.026388 -81.318228       24.4
#
#         DATE  AWND AWND_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  ...  WT08  \
# 0  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 1  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 2  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 3  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
# 4  9/11/2017   NaN             NaN   NaN             NaN  ...   NaN
#
#   WT08_ATTRIBUTES  WT09 WT09_ATTRIBUTES  WT10  WT10_ATTRIBUTES  WT11  \
# 0             NaN   NaN             NaN   NaN              NaN   NaN
# 1             NaN   NaN             NaN   NaN              NaN   NaN
# 2             NaN   NaN             NaN   NaN              NaN   NaN
# 3             NaN   NaN             NaN   NaN              NaN   NaN
# 4             NaN   NaN             NaN   NaN              NaN   NaN
#
#   WT11_ATTRIBUTES                         list  \
# 0             NaN          [30.4109, -86.6475]
# 1             NaN           [29.755, -81.5389]
# 2             NaN      [28.860597, -80.871231]
# 3             NaN          [28.3956, -80.7868]
# 4             NaN  [29.02638751, -81.31822754]
#
#                              Points
# 0          POINT (30.4109 -86.6475)
# 1           POINT (29.755 -81.5389)
# 2      POINT (28.860597 -80.871231)
# 3          POINT (28.3956 -80.7868)
# 4  POINT (29.02638751 -81.31822754)
#
# [5 rows x 44 columns]

# %%
irma.to_csv(r'data\irma_p.csv', index=False)

# %%
irma_s = irma.head(10)

# %%
geopandas.tools.reverse_geocode(irma_s.Points)
# Out:
#       geometry address
# 0  POINT EMPTY    None
# 1  POINT EMPTY    None
# 2  POINT EMPTY    None
# 3  POINT EMPTY    None
# 4  POINT EMPTY    None
# 5  POINT EMPTY    None
# 6  POINT EMPTY    None
# 7  POINT EMPTY    None
# 8  POINT EMPTY    None
# 9  POINT EMPTY    None

# %%
geopandas.tools.reverse_geocode(irma.Points)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 geopandas.tools.reverse_geocode(irma.Points)
#
# File ~\anaconda3\lib\site-packages\geopandas\tools\geocoding.py:118, in reverse_geocode(points, provider, **kwargs)
#     115     provider = "photon"
#     116 throttle_time = _get_throttle_time(provider)
# --> 118 return _query(points, False, provider, throttle_time, **kwargs)
#
# File ~\anaconda3\lib\site-packages\geopandas\tools\geocoding.py:143, in _query(data, forward, provider, throttle_time, **kwargs)
#     141         results[i] = coder.geocode(s)
#     142     else:
# --> 143         results[i] = coder.reverse((s.y, s.x), exactly_one=True)
#     144 except (GeocoderQueryError, ValueError):
#     145     results[i] = (None, None)
#
# File ~\anaconda3\lib\site-packages\geopy\geocoders\photon.py:218, in Photon.reverse(self, query, exactly_one, timeout, language, limit)
#     216 logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     217 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 218 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~\anaconda3\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~\anaconda3\lib\site-packages\geopy\adapters.py:447, in RequestsAdapter.get_json(self, url, timeout, headers)
#     446 def get_json(self, url, *, timeout, headers):
# --> 447     resp = self._request(url, timeout=timeout, headers=headers)
#     448     try:
#     449         return resp.json()
#
# File ~\anaconda3\lib\site-packages\geopy\adapters.py:457, in RequestsAdapter._request(self, url, timeout, headers)
#     455 def _request(self, url, *, timeout, headers):
#     456     try:
# --> 457         resp = self.session.get(url, timeout=timeout, headers=headers)
#     458     except Exception as error:
#     459         message = str(error)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda3\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\anaconda3\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Attempting to get city from another database

# %%
#https://simplemaps.com/data/us-cities
c =  pd.read_csv(r'data\uscities.csv')
c.head()
# Out:
#             city     city_ascii state_id state_name  county_fips  \
# 0      Anchorage      Anchorage       AK     Alaska         2020
# 1      Fairbanks      Fairbanks       AK     Alaska         2090
# 2         Juneau         Juneau       AK     Alaska         2110
# 3         Badger         Badger       AK     Alaska         2090
# 4  Knik-Fairview  Knik-Fairview       AK     Alaska         2170
#
#             county_name      lat       lng  population  density source  \
# 0             Anchorage  61.1508 -149.1091      292545     66.1  shape
# 1  Fairbanks North Star  64.8353 -147.6533       64160    382.2  shape
# 2                Juneau  58.4546 -134.1739       32240      4.6  shape
# 3  Fairbanks North Star  64.8006 -147.3877       19226    114.3  shape
# 4     Matanuska-Susitna  61.5082 -149.6252       18282     92.8  shape
#
#    military  incorporated           timezone  ranking  \
# 0     False          True  America/Anchorage        2
# 1     False          True  America/Anchorage        3
# 2     False          True     America/Juneau        2
# 3     False         False  America/Anchorage        3
# 4     False          True  America/Anchorage        3
#
#                                                 zips          id
# 0  99518 99515 99517 99516 99513 99540 99530 9956...  1840023385
# 1                                  99701 99703 99712  1840023463
# 2          99824 99801 99802 99803 99811 99812 99821  1840023306
# 3                                        99705 99711  1840023690
# 4                                        99623 99654  1840075080

# %%
c = c.loc[c['state_id'] == 'FL']
c.head()
# Out:
#               city    city_ascii state_id state_name  county_fips  \
# 4361         Miami         Miami       FL    Florida        12086
# 4362         Tampa         Tampa       FL    Florida        12057
# 4363       Orlando       Orlando       FL    Florida        12095
# 4364  Jacksonville  Jacksonville       FL    Florida        12031
# 4365      Sarasota      Sarasota       FL    Florida        12115
#
#        county_name      lat      lng  population  density source  military  \
# 4361    Miami-Dade  25.7840 -80.2101     5711945   4945.7  shape     False
# 4362  Hillsborough  27.9945 -82.4447     2683956   1340.7  shape     False
# 4363        Orange  28.4773 -81.3370     1927699    992.0  shape     False
# 4364         Duval  30.3322 -81.6749     1220191    466.3  shape     False
# 4365      Sarasota  27.3387 -82.5432      727388   1518.1  shape     False
#
#       incorporated          timezone  ranking  \
# 4361          True  America/New_York        1
# 4362          True  America/New_York        1
# 4363          True  America/New_York        1
# 4364          True  America/New_York        1
# 4365          True  America/New_York        2
#
#                                                    zips          id
# 4361  33128 33129 33125 33126 33127 33149 33144 3314...  1840015149
# 4362  33629 33621 33620 33619 33616 33613 33617 3361...  1840015982
# 4363  32829 32827 32824 32822 32804 32805 32806 3280...  1840015099
# 4364  32224 32225 32226 32227 32220 32221 32222 3222...  1840015031
# 4365                34232 34234 34237 34236 34239 34276  1840015988

# %%
c = c[['city', 'lat', 'lng']]
c.head()
# Out:
#               city      lat      lng
# 4361         Miami  25.7840 -80.2101
# 4362         Tampa  27.9945 -82.4447
# 4363       Orlando  28.4773 -81.3370
# 4364  Jacksonville  30.3322 -81.6749
# 4365      Sarasota  27.3387 -82.5432

# %%
io =  pd.read_csv(r'data\irma_coord.csv')
io
# Out:
#     Unnamed: 0                                               NAME  LATITUDE  \
# 0           39  FORT PIERCE ST LUCIE CO INTERNATIONAL AIRPORT,...  27.49816
# 1           40      FORT MYERS SW FLORIDA REGIONAL AIRPORT, FL US  26.53805
# 2           59  NORTHWEST FLORIDA BEACHES INTERNATIONAL AIRPOR...  30.34869
# 3           72                      BONIFAY TRI CO AIRPORT, FL US  30.84315
# 4           84                     WHITING FIELD NAS SOUTH, FL US  30.69729
# ..         ...                                                ...       ...
# 72        1039           FORT LAUDERDALE EXECUTIVE AIRPORT, FL US  26.19905
# 73        1040            LAKELAND LINDER REGIONAL AIRPORT, FL US  28.00000
# 74        1041                     MIAMI OPA LOCKA AIRPORT, FL US  25.91017
# 75        1043                TALLAHASSEE REGIONAL AIRPORT, FL US  30.39354
# 76        1048                     ORLANDO SANFORD AIRPORT, FL US  28.77951
#
#     LONGITUDE       DATE   AWND  WSF2  WSF5
# 0   -80.37626  9/11/2017  17.45  44.1  62.0
# 1   -81.75674  9/11/2017  19.24  45.0  59.1
# 2   -85.78835  9/11/2017  19.01  30.0  45.0
# 3   -85.60431  9/11/2017  13.42  23.0  42.9
# 4   -87.02073  9/11/2017  16.33  25.1  36.0
# ..        ...        ...    ...   ...   ...
# 72  -80.17764  9/10/2017  37.13  53.0  74.9
# 73  -82.05000  9/10/2017  21.92  51.0  67.1
# 74  -80.28283  9/10/2017  40.71  55.0  85.0
# 75  -84.35136  9/10/2017  15.66  25.9  36.9
# 76  -81.24356  9/10/2017  21.03  59.1  72.9
#
# [77 rows x 8 columns]

# %%
c.lat = c.lat.round(1)
c.lng = c.lng.round(1)
io.LATITUDE = io.LATITUDE.round(1)
io.LONGITUDE = io.LONGITUDE.round(1)

# %%
c.loc[c['city'] == 'Fort Myers']
# Out:
#             city   lat   lng
# 4408  Fort Myers  26.6 -81.8

# %%
c.loc[c['city'] == 'Miami']
# Out:
#        city   lat   lng
# 4361  Miami  25.8 -80.2

# %%
io
# Out:
#     Unnamed: 0                                               NAME  LATITUDE  \
# 0           39  FORT PIERCE ST LUCIE CO INTERNATIONAL AIRPORT,...      27.5
# 1           40      FORT MYERS SW FLORIDA REGIONAL AIRPORT, FL US      26.5
# 2           59  NORTHWEST FLORIDA BEACHES INTERNATIONAL AIRPOR...      30.4
# 3           72                      BONIFAY TRI CO AIRPORT, FL US      30.8
# 4           84                     WHITING FIELD NAS SOUTH, FL US      30.7
# ..         ...                                                ...       ...
# 72        1039           FORT LAUDERDALE EXECUTIVE AIRPORT, FL US      26.2
# 73        1040            LAKELAND LINDER REGIONAL AIRPORT, FL US      28.0
# 74        1041                     MIAMI OPA LOCKA AIRPORT, FL US      25.9
# 75        1043                TALLAHASSEE REGIONAL AIRPORT, FL US      30.4
# 76        1048                     ORLANDO SANFORD AIRPORT, FL US      28.8
#
#     LONGITUDE       DATE   AWND  WSF2  WSF5
# 0       -80.4  9/11/2017  17.45  44.1  62.0
# 1       -81.8  9/11/2017  19.24  45.0  59.1
# 2       -85.8  9/11/2017  19.01  30.0  45.0
# 3       -85.6  9/11/2017  13.42  23.0  42.9
# 4       -87.0  9/11/2017  16.33  25.1  36.0
# ..        ...        ...    ...   ...   ...
# 72      -80.2  9/10/2017  37.13  53.0  74.9
# 73      -82.0  9/10/2017  21.92  51.0  67.1
# 74      -80.3  9/10/2017  40.71  55.0  85.0
# 75      -84.4  9/10/2017  15.66  25.9  36.9
# 76      -81.2  9/10/2017  21.03  59.1  72.9
#
# [77 rows x 8 columns]
