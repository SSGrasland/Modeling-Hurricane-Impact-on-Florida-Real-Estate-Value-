# %%
#Importing libraries needed
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#opening the dataset to create a dataframe for logistic regression 
matthew = pd.read_csv(r'data\Matthew.csv')
irma =  pd.read_csv(r'data\Irma.csv')
michael =  pd.read_csv(r'data\Michael.csv')

# %%
#dropping rows that have missing value for average wind speed 
matthew = matthew.dropna(subset=['AWND'])
irma = irma.dropna(subset=['AWND'])
michael = michael.dropna(subset=['AWND'])

# %%
matthew.head()
# Out:
#         STATION                                               NAME  LATITUDE  \
# 46  USW00012897                    NAPLES MUNICIPAL AIRPORT, FL US  26.15498
# 49  USW00012896                            MARATHON AIRPORT, FL US  24.72624
# 50  USW00012895  FORT PIERCE ST LUCIE CO INTERNATIONAL AIRPORT,...  27.49816
# 51  USW00012894      FORT MYERS SW FLORIDA REGIONAL AIRPORT, FL US  26.53805
# 71  USW00073805  NORTHWEST FLORIDA BEACHES INTERNATIONAL AIRPOR...  30.34869
#
#     LONGITUDE  ELEVATION       DATE   AWND AWND_ATTRIBUTES  PGTM  \
# 46  -81.77514        2.0  10/8/2016   8.05             ,,W   NaN
# 49  -81.04770        0.9  10/8/2016   4.92             ,,W   NaN
# 50  -80.37626        5.7  10/8/2016   9.62             ,,W   NaN
# 51  -81.75674        8.2  10/8/2016   6.26             ,,W   NaN
# 71  -85.78835       17.1  10/8/2016  10.51             ,,W   NaN
#
#    PGTM_ATTRIBUTES  ...  WT07 WT07_ATTRIBUTES  WT08 WT08_ATTRIBUTES  WT09  \
# ...

# %%
print(matthew.isnull().sum())
print()
print(irma.isnull().sum())
print()
print(michael.isnull().sum())
# Out:
# STATION              0
# NAME                 0
# LATITUDE             0
# LONGITUDE            0
# ELEVATION            0
# DATE                 0
# AWND                 0
# AWND_ATTRIBUTES      0
# PGTM               111
# PGTM_ATTRIBUTES    111
# WDF2                 0
# WDF2_ATTRIBUTES      0
# WDF5                 0
# WDF5_ATTRIBUTES      0
# WDMV               137
# WDMV_ATTRIBUTES    137
# WSF2                 0
# WSF2_ATTRIBUTES      0
# WSF5                 0
# WSF5_ATTRIBUTES      0
# WT01                92
# WT01_ATTRIBUTES     92
# WT02               137
# WT02_ATTRIBUTES    137
# WT03               130
# WT03_ATTRIBUTES    130
# WT04               137
# WT04_ATTRIBUTES    137
# WT05               137
# WT05_ATTRIBUTES    137
# WT06               137
# WT06_ATTRIBUTES    137
# WT07               137
# WT07_ATTRIBUTES    137
# WT08               121
# WT08_ATTRIBUTES    121
# WT09               137
# WT09_ATTRIBUTES    137
# WT10               137
# WT10_ATTRIBUTES    137
# ...

# %%
#dropping attributes 
matthew = matthew.loc[:, ~matthew.columns.str.contains('ATTRIBUTES', 'WT')]
irma = irma.loc[:, ~irma.columns.str.contains('ATTRIBUTES')]
michael = michael.loc[:, ~michael.columns.str.contains('ATTRIBUTES')]

# %%
#dropping attributes, weather types
matthew = matthew.loc[:, ~matthew.columns.str.contains('ATTRIBUTES|WT')]
irma = irma.loc[:, ~irma.columns.str.contains('ATTRIBUTES|WT')]
michael = michael.loc[:, ~michael.columns.str.contains('ATTRIBUTES|WT')]

# %%
matthew = matthew.rename(columns={"WT10": "Tornado", "WT11": "DamagingWinds"})
irma = irma.rename(columns={"WT10": "Tornado", "WT11": "DamagingWinds"})
michael = michael.rename(columns={"WT10": "Tornado", "WT11": "DamagingWinds"})

# %%
#station, elevation, latitude, and longitude 
matthew.drop(['STATION', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'WDF2', 'WDF5', 'PGTM', 'WDMV'], axis=1, inplace=True)
irma.drop(['STATION', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'WDF2', 'WDF5', 'PGTM', 'WDMV'], axis=1, inplace=True)
michael.drop(['STATION', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'WDF2', 'WDF5', 'PGTM', 'WDMV'], axis=1, inplace=True)

# %%
print(matthew.isnull().sum())
print()
print(irma.isnull().sum())
print()
print(michael.isnull().sum())
# Out:
# NAME    0
# DATE    0
# AWND    0
# WSF2    0
# WSF5    0
# dtype: int64
#
# NAME    0
# DATE    0
# AWND    0
# WSF2    1
# WSF5    1
# dtype: int64
#
# NAME    0
# DATE    0
# AWND    0
# WSF2    3
# WSF5    4
# dtype: int64

# %% [markdown]
# NOAA Data
# Average wind speed (AWND)
# Peak gust time (PGTM)
# Direction of fastest 2-minute wind (WDF2) (in degrees)
# Direction of fastest 5-second wind (WDF5) (in degrees)
# Fastest 2-minute wind speed (WSF2) (in meters per second)
# Fastest 5-second wind speed (WSF5) (in meter per second)
# 24-hour wind movement (km or miles as per user preference, miles on Daily Form pdf file) (WDMV)
# Weather types (WT**)

# %% [markdown]
# The cities were interested at looking at are:
# High: Jacksonville, Daytona Beach, Melbourne, Orlando, Vero Beach, Miami, Kendall, West Palm, Pompano, Fort Lauderdale, Panama City, Tallahasee, Panama City Beach, St Augustine
# Low: Fort Myers, Crestview, Miami, Key West, Kendall, Pensacola, Crestview, Destin, Tallahassee, Gainesville, Fort Myers, St. Petersburg

# %%
#Jacksonville, Daytona Beach, Melbourne, Orlando, Vero Beach
matthew_high = matthew.loc[matthew['AWND'] > 24]
matthew_high.to_csv(r'data\matthew_high.csv', index=False)

# %%
#Fort Myers, Crestview, Miami, Key West, Kendall
matthew_low = matthew.loc[matthew['AWND'] < 7]
matthew_low.to_csv(r'data\matthew_low.csv', index=False)

# %%
#Miami, Kendall, West Palm, Pompano, Fort Lauderdale
irma_high = irma.loc[irma['AWND'] > 36]
irma_high.to_csv(r'data\irma_high.csv', index=False)

# %%
#Pensacola, Crestview, Destin, Tallahassee, Gainesville
irma_low = irma.loc[irma['AWND'] < 18]
irma_low.to_csv(r'data\irma_low.csv', index=False)

# %%
#Apalachicola (Panama City), Tallahasee, Mayport (Jacksonville), Northwest (Panama City Beach), St Augustine 
michael_high = michael.loc[michael['AWND'] > 19]
michael_high.to_csv(r'data\michael_high.csv', index=False)

# %%
#Fort Myers, St. Petersburg, Miami, Key West, Kendall
michael_low = michael.loc[michael['AWND'] < 7]
matthew_low.to_csv(r'data\michael_low.csv', index=False)
